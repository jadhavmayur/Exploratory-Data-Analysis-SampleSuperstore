# %% [markdown]
# ### Dataset
# SampleSuperstore

# %% [markdown]
# ### Statement
# Perform Exploratory Data Analysis on dataset ‘SampleSuperstore’
# As a business manager, try to find out the weak areas where you can
# work to make more profit.

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing data

# %%
data=pd.read_csv('/content/drive/Shareddrives/mayur/Spark foundatio/EDA retail/SampleSuperstore.csv')
data.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# * There are 9994 observations and 13 columns

# %%
data.describe(include='number')
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# * Observation :-
#
#  * For Sales mean > median it tells us that it is positively skwed.
#  * For Quantity mean almost same as median it tells us that it is normaly distributed.
#  * For Sales mean almost same as median it tells us that it is normaly distributed.
#  * For Profit mean > median it tells us that it is positively skwed.

# %% [markdown]
# ### Data Preprocessing

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ##### find the number of distinct observation

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ##### Find duplicate values and Remove

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# [9977 rows x 13 columns]

# %% [markdown]
# ### Find the correlation of dataset

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(data.corr(),cmap='rocket_r',annot=True)

# %% [markdown]
# * Sales and Profit are Moderately Correlated.
# * Discount and Profit are Negatively Correlated
# * Quantity and Profit are less Moderately Correlated

# %% [markdown]
# ### Find the covariance of dataset

# %%
data.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount         Profit
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404 -225045.849445
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228   69944.096586
# Quantity     9.104159e+02     278.459923    4.951113    0.003961      34.534769
# Discount     3.868704e+02      -3.627228    0.003961    0.042622     -10.615173
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173   54877.798055

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %%
plt.close();
sns.set_style('whitegrid')
sns.pairplot(data,size=3)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Deleting the variable

# %%
data1=data.drop('Postal Code',axis=1)

# %%
data1.head(2)
# Out:
#       Ship Mode   Segment        Country  ... Quantity Discount    Profit
# 0  Second Class  Consumer  United States  ...        2      0.0   41.9136
# 1  Second Class  Consumer  United States  ...        3      0.0  219.5820
#
# [2 rows x 12 columns]

# %%
plt.figure(figsize=(18,5))
plt.bar('Sub-Category','Category',data=data1)
plt.show()

# %%
# Let's try to visualize the 'State' column from the dataset.
plt.figure(figsize=(18,5))
sns.countplot(x='State',data=data1)
plt.xticks(rotation=90)
plt.show()

# %%
# Let's try to visualize the 'Sub-Category' column from the dataset.
plt.figure(figsize=(18,5))
sns.countplot(x='Sub-Category',data=data1)
plt.xticks(rotation=90)
plt.show()

# %%
## Let's try to visualize the 'Category' column from the dataset.
plt.figure(figsize=(8,5))
sns.countplot('Category',data=data,palette='ocean')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Office supplies Category has highest count around 6000

# %% [markdown]
# #### Analysis of Profit and Sales By Ship mode and Category

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Ship Mode', y='Profit',hue='Category',kind='bar',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * Observation:-
#
#  * Ship mode First Class and Same Day Has highest profit.
#  * Technology shares highest profit

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Ship Mode', y='Sales',hue='Category',kind='bar',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * highest Sales share by technology Category

# %% [markdown]
# ### Analysis of Profit and Sales By Region

# %%
plt.figure(figsize=(20,50))
sns.factorplot(x='Ship Mode', y='Profit',kind='bar',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * West region has highest profit
# *East region has good profit
# * As compare to East,West and south region, cetral region dont have good profit

# %%
plt.figure(figsize=(20,50))
sns.factorplot(x='Region', y='Profit',hue='Category',kind='bar',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * In Central region there is loss due to Furniture category

# %% [markdown]
# ### Analysis of Profit by Sub-Category

# %%
plt.figure(figsize=(20,50))
sns.factorplot(x='Sub-Category', y='Profit',kind='bar',data=data)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * Copiers has highest profit
# * Tables has loss
# * Art,Fasteners and Supplies almost has zero profit

# %% [markdown]
# ### Analysis of Profit by Discount

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Discount', 'Profit', data =data, color = 'r', label= 'Discount')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Observation:-
#
#  * As the discount increases loss also increases

# %% [markdown]
# ### Analysis of profit by City

# %%
data_city=data.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
data_city = data_city.sort_values('Profit')
data_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
#1.Low Profit
data_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'Pink')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %%
#2. High Profit
data_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'Pink')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %% [markdown]
# * 30 Cities which has profit in POSITIVE
# * 30 Cities which has profit in NEGATIVE
# * Jamestown Has highest profit
# * Bethlehem Has highest loss

# %% [markdown]
# #Thank you
